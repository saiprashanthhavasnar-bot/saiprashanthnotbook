# %%
# %sql select * from solix.AAA_DEPARTMENT_RELATION_1 limit 10;
# Out:
# RuntimeError: No database connection found - assign one to a variable named _conn first (e.g. _conn = sqlite3.connect(...)), then use %sql/%%sql
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_line_magic('sql', 'select * from solix.AAA_DEPARTMENT_RELATION_1 limit 10;')
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
# ...

# %%
# %%sql
# SELECT * FROM solix.aaa_department_relation_1 LIMIT 50
# Out:
#     dept_id dept_code      dept_name     location manager_name  budget_amount  \
# 0         1        21            dep          hyd           ss          100.0
# 1        50        70  Department_50  Location_10   Manager_50        50000.0
# 2        51        71  Department_51   Location_1   Manager_51        51000.0
# 3        52        72  Department_52   Location_2   Manager_52        52000.0
# 4        53        73  Department_53   Location_3   Manager_53        53000.0
# 5        54        74  Department_54   Location_4   Manager_54        54000.0
# 6        55        75  Department_55   Location_5   Manager_55        55000.0
# 7        56        76  Department_56   Location_6   Manager_56        56000.0
# 8        57        77  Department_57   Location_7   Manager_57        57000.0
# 9        58        78  Department_58   Location_8   Manager_58        58000.0
# 10       59        79  Department_59   Location_9   Manager_59        59000.0
# ...

# %%
# %%sql
# SELECT * FROM solix.aaa_department_relation_1 LIMIT 50
# Out:
#     dept_id dept_code      dept_name     location manager_name  budget_amount  \
# 0         1        21            dep          hyd           ss          100.0
# 1        50        70  Department_50  Location_10   Manager_50        50000.0
# 2        51        71  Department_51   Location_1   Manager_51        51000.0
# 3        52        72  Department_52   Location_2   Manager_52        52000.0
# 4        53        73  Department_53   Location_3   Manager_53        53000.0
# 5        54        74  Department_54   Location_4   Manager_54        54000.0
# 6        55        75  Department_55   Location_5   Manager_55        55000.0
# 7        56        76  Department_56   Location_6   Manager_56        56000.0
# 8        57        77  Department_57   Location_7   Manager_57        57000.0
# 9        58        78  Department_58   Location_8   Manager_58        58000.0
# 10       59        79  Department_59   Location_9   Manager_59        59000.0
# ...
